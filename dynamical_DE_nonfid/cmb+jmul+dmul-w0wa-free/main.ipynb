# %%
import numpy as np
import pandas as pd
from starfish.plot import *

# %%
from starfish.set import settings
settings.cosmo_value
# Out:
# [0.32, 0.049, 0.67, 0.96, 0.81, 0.06, 3.044, -0.758, -0.82]

# %%
def var_filter(fisher,lcdm,neff_fixed):
    df=fisher.copy()
    if lcdm:
        df=df.drop('w0',axis=0)
        df=df.drop('w0',axis=1)
        df=df.drop('wa',axis=0)
        df=df.drop('wa',axis=1)
    if neff_fixed:
        df=df.drop('N_eff',axis=0)
        df=df.drop('N_eff',axis=1)

    return df

# %% [markdown]
# # nuisance parameters of different tracers/surveys should be independent of each other

# %%
JPAS_multi=var_filter(pd.read_excel('../data/jpas_all/valid.xlsx',header=0,index_col=0),lcdm=False,neff_fixed=False)
cov=pd.DataFrame(np.linalg.inv(JPAS_multi.values),index=JPAS_multi.index,columns=JPAS_multi.columns)
JPAS_multi_valid=np.linalg.inv(cov.iloc[:settings.cosmo_num,:settings.cosmo_num].values)

# %%
DESI_multi=var_filter(pd.read_excel('../data/DESI_all/valid.xlsx',header=0,index_col=0),lcdm=False,neff_fixed=False)
cov=pd.DataFrame(np.linalg.inv(DESI_multi.values),index=DESI_multi.index,columns=DESI_multi.columns)
DESI_multi_valid=np.linalg.inv(cov.iloc[:settings.cosmo_num,:settings.cosmo_num].values)

# %%
PFS_ELG=var_filter(pd.read_excel('../data/PFS/fisher.xlsx',header=0,index_col=0),lcdm=False,neff_fixed=False)
cov=pd.DataFrame(np.linalg.inv(PFS_ELG.values),index=PFS_ELG.index,columns=PFS_ELG.columns)
PFS_ELG_valid=np.linalg.inv(cov.iloc[:settings.cosmo_num,:settings.cosmo_num].values)

# %%
cmb_fisher=var_filter(pd.read_excel('../data/CMB/all.xlsx',header=0,index_col=0),lcdm=False,neff_fixed=False)
cmb_fisher
# Out:
#               omega_m0      omega_b0             h           n_s  \
# omega_m0  1.832635e+08 -6.900284e+08  1.362112e+08 -4.758042e+06
# omega_b0 -6.900284e+08  3.029247e+09 -4.576080e+08  3.225261e+07
# h         1.362112e+08 -4.576080e+08  1.120751e+08 -1.915047e+06
# n_s      -4.758042e+06  3.225261e+07 -1.915047e+06  1.048669e+06
# sigma_8  -5.746445e+07  2.230394e+08 -3.813100e+07  1.680655e+06
# m_nu     -1.235692e+07  4.722996e+07 -7.835263e+06  3.181700e+05
# N_eff    -6.552094e+06  2.324241e+07 -5.457936e+06  1.135218e+05
# tau       4.454907e+07 -1.716450e+08  2.958343e+07 -1.294412e+06
# w0        2.340521e+06 -9.264716e+06  3.655445e+06 -1.428846e+05
# wa        3.384164e+05 -1.364851e+06  7.486781e+05 -2.853892e+04
#
#                sigma_8          m_nu         N_eff           tau  \
# omega_m0 -5.746445e+07 -1.235692e+07 -6.552094e+06  4.454907e+07
# omega_b0  2.230394e+08  4.722996e+07  2.324241e+07 -1.716450e+08
# h        -3.813100e+07 -7.835263e+06 -5.457936e+06  2.958343e+07
# n_s       1.680655e+06  3.181700e+05  1.135218e+05 -1.294412e+06
# sigma_8   2.236678e+07  5.249881e+06  1.590900e+06 -1.730748e+07
# m_nu      5.249881e+06  1.281325e+06  2.949168e+05 -4.086740e+06
# N_eff     1.590900e+06  2.949168e+05  2.869853e+05 -1.229446e+06
# tau      -1.730748e+07 -4.086740e+06 -1.229446e+06  1.373224e+07
# w0        1.355248e+06  5.324056e+05 -3.051864e+05 -1.087846e+06
# wa        4.330255e+05  1.552160e+05 -6.932283e+04 -3.453244e+05
#
#                     w0            wa
# omega_m0  2.340521e+06  3.384164e+05
# omega_b0 -9.264716e+06 -1.364851e+06
# h         3.655445e+06  7.486781e+05
# n_s      -1.428846e+05 -2.853892e+04
# sigma_8   1.355248e+06  4.330255e+05
# m_nu      5.324056e+05  1.552160e+05
# N_eff    -3.051864e+05 -6.932283e+04
# tau      -1.087846e+06 -3.453244e+05
# w0        1.102819e+06  2.809177e+05
# wa        2.809177e+05  7.193339e+04

# %%
cmb_cov=pd.DataFrame(np.linalg.inv(cmb_fisher.values),index=cmb_fisher.index,columns=cmb_fisher.columns)
cmb_cov_marg=cmb_cov.drop('tau',axis=0)
cmb_cov_marg=cmb_cov_marg.drop('tau',axis=1)
cmb_fisher_marg=pd.DataFrame(np.linalg.inv(cmb_cov_marg),index=settings.var_name,columns=settings.var_name)
cmb_fisher_marg
# Out:
#               omega_m0      omega_b0             h           n_s  \
# omega_m0  3.874082e+07 -1.331911e+08  4.023887e+07 -5.588097e+05
# omega_b0 -1.331911e+08  8.837859e+08 -8.783243e+07  1.607321e+07
# h         4.023887e+07 -8.783243e+07  4.834339e+07  8.735118e+05
# n_s      -5.588097e+05  1.607321e+07  8.735118e+05  9.266571e+05
# sigma_8  -1.316862e+06  6.706083e+06 -8.454146e+05  4.923767e+04
# m_nu      9.009658e+05 -3.851899e+06  9.688214e+05 -6.704948e+04
# N_eff    -2.563621e+06  7.875055e+06 -2.809335e+06 -2.366797e+03
# w0        5.869628e+06 -2.286216e+07  5.998998e+06 -2.454259e+05
# wa        1.458691e+06 -5.681204e+06  1.492612e+06 -6.108949e+04
#
#                sigma_8          m_nu         N_eff            w0            wa
# omega_m0 -1.316862e+06  9.009658e+05 -2.563621e+06  5.869628e+06  1.458691e+06
# omega_b0  6.706083e+06 -3.851899e+06  7.875055e+06 -2.286216e+07 -5.681204e+06
# h        -8.454146e+05  9.688214e+05 -2.809335e+06  5.998998e+06  1.492612e+06
# n_s       4.923767e+04 -6.704948e+04 -2.366797e+03 -2.454259e+05 -6.108949e+04
# sigma_8   5.532396e+05  9.914294e+04  4.136306e+04 -1.582268e+04 -2.205387e+03
# m_nu      9.914294e+04  6.510407e+04 -7.096857e+04  2.086606e+05  5.244682e+04
# N_eff     4.136306e+04 -7.096857e+04  1.769132e+05 -4.025812e+05 -1.002397e+05
# w0       -1.582268e+04  2.086606e+05 -4.025812e+05  1.016641e+06  2.535616e+05
# wa       -2.205387e+03  5.244682e+04 -1.002397e+05  2.535616e+05  6.324953e+04

# %% [markdown]
# # CMB-S4 + LiteBIRD + J-PAS multitracer + PFS ELG

# %%
fisher1=pd.DataFrame(JPAS_multi_valid+PFS_ELG_valid,index=settings.var_name,columns=settings.var_name)
fisher1.to_excel('../data/combined/pelg+jmul-w0wacdm-free.xlsx')
cov1=pd.DataFrame(np.linalg.inv(fisher1.values),index=settings.var_name,columns=settings.var_name)

# %%
fisher1_combined=fisher1+cmb_fisher_marg
fisher1_combined.to_excel('../data/combined/cmb+pelg+jmul-w0wacdm-free.xlsx')
cov1_combined=pd.DataFrame(np.linalg.inv(fisher1_combined),index=fisher1_combined.index,columns=fisher1_combined.columns)
cov1_combined
# Out:
#               omega_m0      omega_b0             h           n_s  \
# omega_m0  7.836868e-06  7.686710e-07 -4.631103e-06  2.377226e-07
# omega_b0  7.686710e-07  1.749116e-07 -1.154970e-06 -7.184082e-08
# h        -4.631103e-06 -1.154970e-06  8.114520e-06  9.441575e-07
# n_s       2.377226e-07 -7.184082e-08  9.441575e-07  5.217681e-06
# sigma_8  -1.103668e-05 -1.257119e-06  8.238678e-06  4.632893e-07
# m_nu      6.522673e-05 -2.354346e-06  1.858196e-05 -8.084927e-06
# N_eff     2.948099e-05 -2.383443e-06  3.481819e-05  5.659406e-05
# w0        7.999754e-05  1.057305e-05 -6.275413e-05  3.295991e-05
# wa       -3.302410e-04 -1.905706e-05  1.038968e-04 -6.503988e-05
#
#                sigma_8      m_nu     N_eff        w0        wa
# omega_m0 -1.103668e-05  0.000065  0.000029  0.000080 -0.000330
# omega_b0 -1.257119e-06 -0.000002 -0.000002  0.000011 -0.000019
# h         8.238678e-06  0.000019  0.000035 -0.000063  0.000104
# n_s       4.632893e-07 -0.000008  0.000057  0.000033 -0.000065
# sigma_8   2.729163e-05 -0.000145  0.000005 -0.000134  0.000614
# m_nu     -1.446378e-04  0.001831  0.000287  0.000451 -0.005032
# N_eff     5.492614e-06  0.000287  0.001307  0.000489 -0.001788
# w0       -1.340825e-04  0.000451  0.000489  0.001976 -0.006906
# wa        6.142468e-04 -0.005032 -0.001788 -0.006906  0.032432

# %%
name_width=max([len(v) for v in settings.var_name])
error_dict=dict(zip(settings.var_name,np.sqrt(np.diag(cov1_combined.values))))
print('1-sigma errors:')
for key in error_dict.keys():
    print(f'-- {key.rjust(name_width)}: {error_dict[key]:.1e}')
# Out:
# 1-sigma errors:
# -- omega_m0: 2.8e-03
# -- omega_b0: 4.2e-04
# --        h: 2.8e-03
# --      n_s: 2.3e-03
# --  sigma_8: 5.2e-03
# --     m_nu: 4.3e-02
# --    N_eff: 3.6e-02
# --       w0: 4.4e-02
# --       wa: 1.8e-01

# %% [markdown]
# # CMB-S4 + LiteBIRD + DESI multitracer

# %%
DESI_combined=DESI_multi_valid+cmb_fisher_marg
DESI_combined.to_excel('../data/combined/cmb+dmul-w0wacdm-free.xlsx')
covd_combined=pd.DataFrame(np.linalg.inv(DESI_combined),index=DESI_combined.index,columns=DESI_combined.columns)
covd_combined
# Out:
#               omega_m0      omega_b0             h           n_s  \
# omega_m0  6.273855e-06  4.615009e-07 -2.425744e-06  1.337296e-06
# omega_b0  4.615009e-07  1.071726e-07 -7.114504e-07 -7.788307e-08
# h        -2.425744e-06 -7.114504e-07  5.162752e-06  7.694406e-07
# n_s       1.337296e-06 -7.788307e-08  7.694406e-07  4.422675e-06
# sigma_8  -6.771150e-06 -6.619080e-07  4.089390e-06 -6.833252e-07
# m_nu      5.007532e-05 -1.948101e-06  2.028820e-05  1.381866e-05
# N_eff     4.804050e-05 -1.863178e-06  2.917466e-05  4.944060e-05
# w0        3.984781e-05  5.959777e-06 -3.433390e-05  2.145799e-05
# wa       -1.696977e-04 -9.540989e-06  3.799669e-05 -7.112355e-05
#
#                sigma_8      m_nu     N_eff        w0        wa
# omega_m0 -6.771150e-06  0.000050  0.000048  0.000040 -0.000170
# omega_b0 -6.619080e-07 -0.000002 -0.000002  0.000006 -0.000010
# h         4.089390e-06  0.000020  0.000029 -0.000034  0.000038
# n_s      -6.833252e-07  0.000014  0.000049  0.000021 -0.000071
# sigma_8   1.889540e-05 -0.000106 -0.000011 -0.000064  0.000326
# m_nu     -1.059157e-04  0.001282  0.000548  0.000094 -0.002363
# N_eff    -1.135105e-05  0.000548  0.001266  0.000319 -0.001647
# w0       -6.385361e-05  0.000094  0.000319  0.000813 -0.002385
# wa        3.255058e-04 -0.002363 -0.001647 -0.002385  0.011003

# %%
name_width=max([len(v) for v in settings.var_name])
error_dict=dict(zip(settings.var_name,np.sqrt(np.diag(covd_combined.values))))
print('1-sigma errors:')
for key in error_dict.keys():
    print(f'-- {key.rjust(name_width)}: {error_dict[key]:.1e}')
# Out:
# 1-sigma errors:
# -- omega_m0: 2.5e-03
# -- omega_b0: 3.3e-04
# --        h: 2.3e-03
# --      n_s: 2.1e-03
# --  sigma_8: 4.3e-03
# --     m_nu: 3.6e-02
# --    N_eff: 3.6e-02
# --       w0: 2.9e-02
# --       wa: 1.0e-01
