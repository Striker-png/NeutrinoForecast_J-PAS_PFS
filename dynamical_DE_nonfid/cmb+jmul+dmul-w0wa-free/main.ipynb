# %%
import numpy as np
import pandas as pd
from starfish.plot import *

# %%
from starfish.set import settings
settings.cosmo_value
# Out:
# [0.32, 0.049, 0.67, 0.96, 0.81, 0.06, 3.044, -0.758, -0.82]

# %%
def var_filter(fisher,lcdm,neff_fixed):
    df=fisher.copy()
    if lcdm:
        df=df.drop('w0',axis=0)
        df=df.drop('w0',axis=1)
        df=df.drop('wa',axis=0)
        df=df.drop('wa',axis=1)
    if neff_fixed:
        df=df.drop('N_eff',axis=0)
        df=df.drop('N_eff',axis=1)

    return df

# %% [markdown]
# # nuisance parameters of different tracers/surveys should be independent of each other

# %%
JPAS_multi=var_filter(pd.read_excel('../data/jpas_all/valid.xlsx',header=0,index_col=0),lcdm=False,neff_fixed=False)
cov=pd.DataFrame(np.linalg.inv(JPAS_multi.values),index=JPAS_multi.index,columns=JPAS_multi.columns)
JPAS_multi_valid=np.linalg.inv(cov.iloc[:settings.cosmo_num,:settings.cosmo_num].values)

# %%
DESI_multi=var_filter(pd.read_excel('../data/DESI_all/valid.xlsx',header=0,index_col=0),lcdm=False,neff_fixed=False)
cov=pd.DataFrame(np.linalg.inv(DESI_multi.values),index=DESI_multi.index,columns=DESI_multi.columns)
DESI_multi_valid=np.linalg.inv(cov.iloc[:settings.cosmo_num,:settings.cosmo_num].values)

# %%
PFS_ELG=var_filter(pd.read_excel('../data/PFS/fisher.xlsx',header=0,index_col=0),lcdm=False,neff_fixed=False)
cov=pd.DataFrame(np.linalg.inv(PFS_ELG.values),index=PFS_ELG.index,columns=PFS_ELG.columns)
PFS_ELG_valid=np.linalg.inv(cov.iloc[:settings.cosmo_num,:settings.cosmo_num].values)

# %%
cmb_fisher=var_filter(pd.read_excel('../data/CMB/all.xlsx',header=0,index_col=0),lcdm=False,neff_fixed=False)
cmb_fisher
# Out:
#               omega_m0      omega_b0             h           n_s  \
# omega_m0  1.797263e+08 -6.842797e+08  1.331641e+08 -5.301486e+06
# omega_b0 -6.842797e+08  3.010811e+09 -4.532745e+08  3.306874e+07
# h         1.331641e+08 -4.532745e+08  1.093745e+08 -2.368002e+06
# n_s      -5.301486e+06  3.306874e+07 -2.368002e+06  9.367314e+05
# sigma_8  -5.614296e+07  2.211806e+08 -3.700289e+07  1.900677e+06
# m_nu     -1.199894e+07  4.678221e+07 -7.528183e+06  3.795343e+05
# N_eff    -6.436719e+06  2.301783e+07 -5.358457e+06  1.299685e+05
# tau       4.348511e+07 -1.701461e+08  2.867519e+07 -1.470976e+06
# w0        2.538006e+06 -9.319113e+06  3.826963e+06 -1.014404e+05
# wa        3.935233e+05 -1.386726e+06  7.964486e+05 -1.723029e+04
#
#                sigma_8          m_nu         N_eff           tau  \
# omega_m0 -5.614296e+07 -1.199894e+07 -6.436719e+06  4.348511e+07
# omega_b0  2.211806e+08  4.678221e+07  2.301783e+07 -1.701461e+08
# h        -3.700289e+07 -7.528183e+06 -5.358457e+06  2.867519e+07
# n_s       1.900677e+06  3.795343e+05  1.299685e+05 -1.470976e+06
# sigma_8   2.182259e+07  5.099105e+06  1.551996e+06 -1.686963e+07
# m_nu      5.099105e+06  1.239055e+06  2.847650e+05 -3.965440e+06
# N_eff     1.551996e+06  2.847650e+05  2.828208e+05 -1.198112e+06
# tau      -1.686963e+07 -3.965440e+06 -1.198112e+06  1.337987e+07
# w0        1.254380e+06  5.024161e+05 -3.090645e+05 -1.006796e+06
# wa        4.054638e+05  1.470706e+05 -7.046281e+04 -3.231748e+05
#
#                     w0            wa
# omega_m0  2.538006e+06  3.935233e+05
# omega_b0 -9.319113e+06 -1.386726e+06
# h         3.826963e+06  7.964486e+05
# n_s      -1.014404e+05 -1.723029e+04
# sigma_8   1.254380e+06  4.054638e+05
# m_nu      5.024161e+05  1.470706e+05
# N_eff    -3.090645e+05 -7.046281e+04
# tau      -1.006796e+06 -3.231748e+05
# w0        1.074705e+06  2.734625e+05
# wa        2.734625e+05  6.995284e+04

# %%
cmb_cov=pd.DataFrame(np.linalg.inv(cmb_fisher.values),index=cmb_fisher.index,columns=cmb_fisher.columns)
cmb_cov_marg=cmb_cov.drop('tau',axis=0)
cmb_cov_marg=cmb_cov_marg.drop('tau',axis=1)
cmb_fisher_marg=pd.DataFrame(np.linalg.inv(cmb_cov_marg),index=settings.var_name,columns=settings.var_name)
cmb_fisher_marg
# Out:
#               omega_m0      omega_b0             h           n_s  \
# omega_m0  3.839799e+07 -1.312982e+08  3.996861e+07 -5.207546e+05
# omega_b0 -1.312982e+08  8.471369e+08 -8.862440e+07  1.436297e+07
# h         3.996861e+07 -8.862440e+07  4.791905e+07  7.845344e+05
# n_s      -5.207546e+05  1.436297e+07  7.845344e+05  7.750130e+05
# sigma_8  -1.315980e+06  6.656771e+06 -8.485838e+05  4.603770e+04
# m_nu      8.888947e+05 -3.644587e+06  9.703854e+05 -5.642424e+04
# N_eff    -2.542807e+06  7.781956e+06 -2.790713e+06 -1.751280e+03
# w0        5.810132e+06 -2.212210e+07  5.984686e+06 -2.121270e+05
# wa        1.443854e+06 -5.496401e+06  1.489063e+06 -5.275996e+04
#
#                sigma_8          m_nu         N_eff            w0            wa
# omega_m0 -1.315980e+06  8.888947e+05 -2.542807e+06  5.810132e+06  1.443854e+06
# omega_b0  6.656771e+06 -3.644587e+06  7.781956e+06 -2.212210e+07 -5.496401e+06
# h        -8.485838e+05  9.703854e+05 -2.790713e+06  5.984686e+06  1.489063e+06
# n_s       4.603770e+04 -5.642424e+04 -1.751280e+03 -2.121270e+05 -5.275996e+04
# sigma_8   5.529902e+05  9.939137e+04  4.138998e+04 -1.500960e+04 -2.002056e+03
# m_nu      9.939137e+04  6.380337e+04 -7.032371e+04  2.040285e+05  5.129017e+04
# N_eff     4.138998e+04 -7.032371e+04  1.755349e+05 -3.992188e+05 -9.940177e+04
# w0       -1.500960e+04  2.040285e+05 -3.992188e+05  9.989463e+05  2.491446e+05
# wa       -2.002056e+03  5.129017e+04 -9.940177e+04  2.491446e+05  6.214694e+04

# %% [markdown]
# # SO + LiteBIRD + J-PAS multitracer + PFS ELG

# %%
fisher1=pd.DataFrame(JPAS_multi_valid+PFS_ELG_valid,index=settings.var_name,columns=settings.var_name)
fisher1.to_excel('../data/combined/pelg+jmul-w0wacdm-free.xlsx')
cov1=pd.DataFrame(np.linalg.inv(fisher1.values),index=settings.var_name,columns=settings.var_name)

# %%
fisher1_combined=fisher1+cmb_fisher_marg
fisher1_combined.to_excel('../data/combined/cmb+pelg+jmul-w0wacdm-free.xlsx')
cov1_combined=pd.DataFrame(np.linalg.inv(fisher1_combined),index=fisher1_combined.index,columns=fisher1_combined.columns)
cov1_combined
# Out:
#               omega_m0      omega_b0         h           n_s       sigma_8  \
# omega_m0  7.948260e-06  7.595760e-07 -0.000005  9.646582e-08 -1.110463e-05
# omega_b0  7.595760e-07  1.789731e-07 -0.000001 -8.996276e-08 -1.262201e-06
# h        -4.535526e-06 -1.184760e-06  0.000008  1.032914e-06  8.250511e-06
# n_s       9.646582e-08 -8.996276e-08  0.000001  5.909852e-06  6.030339e-07
# sigma_8  -1.110463e-05 -1.262201e-06  0.000008  6.030339e-07  2.738992e-05
# m_nu      6.803543e-05 -2.820083e-06  0.000023 -9.838226e-06 -1.456750e-04
# N_eff     3.019865e-05 -2.659271e-06  0.000037  5.942304e-05  5.617854e-06
# w0        7.943634e-05  1.059655e-05 -0.000063  3.553535e-05 -1.339400e-04
# wa       -3.349877e-04 -1.792792e-05  0.000095 -6.936217e-05  6.157198e-04
#
#               m_nu     N_eff        w0        wa
# omega_m0  0.000068  0.000030  0.000079 -0.000335
# omega_b0 -0.000003 -0.000003  0.000011 -0.000018
# h         0.000023  0.000037 -0.000063  0.000095
# n_s      -0.000010  0.000059  0.000036 -0.000069
# sigma_8  -0.000146  0.000006 -0.000134  0.000616
# m_nu      0.001921  0.000317  0.000436 -0.005204
# N_eff     0.000317  0.001341  0.000499 -0.001889
# w0        0.000436  0.000499  0.001991 -0.006912
# wa       -0.005204 -0.001889 -0.006912  0.032866

# %%
name_width=max([len(v) for v in settings.var_name])
error_dict=dict(zip(settings.var_name,np.sqrt(np.diag(cov1_combined.values))))
print('1-sigma errors:')
for key in error_dict.keys():
    print(f'-- {key.rjust(name_width)}: {error_dict[key]:.1e}')
# Out:
# 1-sigma errors:
# -- omega_m0: 2.8e-03
# -- omega_b0: 4.2e-04
# --        h: 2.9e-03
# --      n_s: 2.4e-03
# --  sigma_8: 5.2e-03
# --     m_nu: 4.4e-02
# --    N_eff: 3.7e-02
# --       w0: 4.5e-02
# --       wa: 1.8e-01

# %% [markdown]
# # SO + LiteBIRD + DESI multitracer

# %%
DESI_combined=DESI_multi_valid+cmb_fisher_marg
DESI_combined.to_excel('../data/combined/cmb+dmul-w0wacdm-free.xlsx')
covd_combined=pd.DataFrame(np.linalg.inv(DESI_combined),index=DESI_combined.index,columns=DESI_combined.columns)
covd_combined
# Out:
#               omega_m0      omega_b0             h           n_s  \
# omega_m0  6.410932e-06  4.512914e-07 -2.311123e-06  1.398340e-06
# omega_b0  4.512914e-07  1.084624e-07 -7.221025e-07 -9.642214e-08
# h        -2.311123e-06 -7.221025e-07  5.268445e-06  8.688640e-07
# n_s       1.398340e-06 -9.642214e-08  8.688640e-07  5.053278e-06
# sigma_8  -6.808230e-06 -6.615120e-07  4.071085e-06 -6.910466e-07
# m_nu      5.251522e-05 -2.143658e-06  2.239244e-05  1.521548e-05
# N_eff     5.051708e-05 -2.100678e-06  3.141093e-05  5.286330e-05
# w0        3.952242e-05  5.977186e-06 -3.463475e-05  2.253258e-05
# wa       -1.732789e-04 -9.232782e-06  3.493461e-05 -7.616779e-05
#
#                sigma_8      m_nu     N_eff        w0        wa
# omega_m0 -6.808230e-06  0.000053  0.000051  0.000040 -0.000173
# omega_b0 -6.615120e-07 -0.000002 -0.000002  0.000006 -0.000009
# h         4.071085e-06  0.000022  0.000031 -0.000035  0.000035
# n_s      -6.910466e-07  0.000015  0.000053  0.000023 -0.000076
# sigma_8   1.893913e-05 -0.000107 -0.000012 -0.000064  0.000327
# m_nu     -1.065608e-04  0.001326  0.000593  0.000088 -0.002427
# N_eff    -1.194496e-05  0.000593  0.001320  0.000319 -0.001725
# w0       -6.397445e-05  0.000088  0.000319  0.000819 -0.002388
# wa        3.269341e-04 -0.002427 -0.001725 -0.002388  0.011125

# %%
name_width=max([len(v) for v in settings.var_name])
error_dict=dict(zip(settings.var_name,np.sqrt(np.diag(covd_combined.values))))
print('1-sigma errors:')
for key in error_dict.keys():
    print(f'-- {key.rjust(name_width)}: {error_dict[key]:.1e}')
# Out:
# 1-sigma errors:
# -- omega_m0: 2.5e-03
# -- omega_b0: 3.3e-04
# --        h: 2.3e-03
# --      n_s: 2.2e-03
# --  sigma_8: 4.4e-03
# --     m_nu: 3.6e-02
# --    N_eff: 3.6e-02
# --       w0: 2.9e-02
# --       wa: 1.1e-01
