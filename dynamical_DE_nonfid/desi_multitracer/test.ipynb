# %%
import numpy as np
from starfish.set import settings

# %%
from starfish.galaxy.power import P_lin_w0wacdm
from starfish.plot import check_wiggle
pars,res,PK=P_lin_w0wacdm(*settings.cosmo_value)
check_wiggle(PK,window_array=settings.window_len)

# %%
from starfish.galaxy.multitracer import get_Fisher
fisher=get_Fisher(lcdm=False)
# Out:
# process started!
# fiducial volumes:
# V_fid (0.1) = 2.51e+08
# V_fid (0.3) = 1.43e+09
# V_fid (0.5) = 3.11e+09
# V_fid (0.7) = 4.85e+09
# V_fid (0.9) = 6.43e+09
# V_fid (1.1) = 7.74e+09
# V_fid (1.3) = 8.76e+09
# V_fid (1.5) = 9.51e+09
# V_fid (1.7) = 1.00e+10
# fiducial biases:
# #################### tracer: BGS ####################
# b_fid (0.1) = 1.41
# b_fid (0.3) = 1.57
# b_fid (0.5) = 1.75
# b_fid (0.7) = 1.93
# b_fid (0.9) = 2.12
# b_fid (1.1) = 2.31
# b_fid (1.3) = 2.51
# b_fid (1.5) = 2.71
# b_fid (1.7) = 2.92
# #################### tracer: LRG ####################
# b_fid (0.1) = 1.79
# b_fid (0.3) = 2.00
# b_fid (0.5) = 2.22
# b_fid (0.7) = 2.45
# b_fid (0.9) = 2.69
# b_fid (1.1) = 2.93
# b_fid (1.3) = 3.19
# b_fid (1.5) = 3.44
# b_fid (1.7) = 3.70
# #################### tracer: ELG ####################
# b_fid (0.1) = 0.89
# b_fid (0.3) = 0.99
# b_fid (0.5) = 1.09
# b_fid (0.7) = 1.21
# b_fid (0.9) = 1.33
# b_fid (1.1) = 1.45
# b_fid (1.3) = 1.57
# b_fid (1.5) = 1.70
# b_fid (1.7) = 1.83
# #################### tracer: QSO ####################
# b_fid (0.1) = 0.88
# b_fid (0.3) = 1.02
# b_fid (0.5) = 1.18
# b_fid (0.7) = 1.37
# b_fid (0.9) = 1.57
# b_fid (1.1) = 1.80
# b_fid (1.3) = 2.06
# b_fid (1.5) = 2.34
# b_fid (1.7) = 2.64
# fiducial values:
# --   omega_m0: 0.3200000900104817
# --   omega_b0: 0.049
# --          h: 0.67
# --        n_s: 0.96
# --    sigma_8: 0.8099999999999995
# --       m_nu: 0.06000375968353048
# --      N_eff: 3.0440000000000005
# --         w0: -0.758
# --         wa: -0.82
# --  p_s1(BGS): 0.0
# --  p_s1(LRG): 0.0
# --  p_s1(ELG): 0.0
# --  p_s1(QSO): 0.0
# --  p_s2(BGS): 0.0
# --  p_s2(LRG): 0.0
# --  p_s2(ELG): 0.0
# --  p_s2(QSO): 0.0
# --  p_s3(BGS): 0.0
# --  p_s3(LRG): 0.0
# --  p_s3(ELG): 0.0
# --  p_s3(QSO): 0.0
# --  p_s4(BGS): 0.0
# --  p_s4(LRG): 0.0
# --  p_s4(ELG): 0.0
# --  p_s4(QSO): 0.0
# --  p_s5(BGS): 0.0
# --  p_s5(LRG): 0.0
# --  p_s5(ELG): 0.0
# --  p_s5(QSO): 0.0
# --  p_s6(BGS): 0.0
# --  p_s6(LRG): 0.0
# --  p_s6(ELG): 0.0
# --  p_s6(QSO): 0.0
# --  p_s7(BGS): 0.0
# --  p_s7(LRG): 0.0
# --  p_s7(ELG): 0.0
# --  p_s7(QSO): 0.0
# --  p_s8(BGS): 0.0
# --  p_s8(LRG): 0.0
# --  p_s8(ELG): 0.0
# --  p_s8(QSO): 0.0
# --  p_s9(BGS): 0.0
# --  p_s9(LRG): 0.0
# --  p_s9(ELG): 0.0
# --  p_s9(QSO): 0.0
# -- lnbs1(BGS): 0.08699585711830814
# -- lnbs1(LRG): 0.32495449421765854
# -- lnbs1(ELG): -0.38002714398928955
# -- lnbs1(QSO): -0.38736760735219433
# -- lnbs2(BGS): 0.09031583537232137
# -- lnbs2(LRG): 0.32827447247167185
# -- lnbs2(ELG): -0.3767071657352764
# -- lnbs2(QSO): -0.3446543827710429
# -- lnbs3(BGS): 0.09356828562721238
# -- lnbs3(LRG): 0.33152692272656276
# -- lnbs3(ELG): -0.3734547154803855
# -- lnbs3(QSO): -0.29815814528180695
# -- lnbs4(BGS): 0.09583949766857255
# -- lnbs4(LRG): 0.3337981347679228
# -- lnbs4(ELG): -0.3711835034390252
# -- lnbs4(QSO): -0.2497580386775643
# -- lnbs5(BGS): 0.09711419222766633
# -- lnbs5(LRG): 0.3350728293270166
# -- lnbs5(ELG): -0.3699088088799315
# -- lnbs5(QSO): -0.20043827097024433
# -- lnbs6(BGS): 0.09765317668269506
# -- lnbs6(LRG): 0.33561181378204546
# -- lnbs6(ELG): -0.3693698244249027
# -- lnbs6(QSO): -0.15080453282016637
# -- lnbs7(BGS): 0.09772972588647988
# -- lnbs7(LRG): 0.3356883629858303
# -- lnbs7(ELG): -0.36929327522111793
# -- lnbs7(QSO): -0.10129290307011288
# -- lnbs8(BGS): 0.09755058992902126
# -- lnbs8(LRG): 0.33550922702837155
# -- lnbs8(ELG): -0.36947241117857677
# -- lnbs8(QSO): -0.05224054131678362
# -- lnbs9(BGS): 0.09725235118742634
# -- lnbs9(LRG): 0.3352109882867767
# -- lnbs9(ELG): -0.3697706499201715
# -- lnbs9(QSO): -0.003908014817407732
# calculating fiducial H(z), DA(z) and f(z,k)...  done!
# all necessary fiducial values done!
# calculating partial derivatives w.r.t cosmological parameters...
# (01/18) a power spectrum of one set of parameters done!
# (02/18) a power spectrum of one set of parameters done!
# (03/18) a power spectrum of one set of parameters done!
# (04/18) a power spectrum of one set of parameters done!
# (05/18) a power spectrum of one set of parameters done!
# (06/18) a power spectrum of one set of parameters done!
# (07/18) a power spectrum of one set of parameters done!
# (08/18) a power spectrum of one set of parameters done!
# (09/18) a power spectrum of one set of parameters done!
# (10/18) a power spectrum of one set of parameters done!
# (11/18) a power spectrum of one set of parameters done!
# (12/18) a power spectrum of one set of parameters done!
# (13/18) a power spectrum of one set of parameters done!
# (14/18) a power spectrum of one set of parameters done!
# (15/18) a power spectrum of one set of parameters done!
# (16/18) a power spectrum of one set of parameters done!
# (17/18) a power spectrum of one set of parameters done!
# (18/18) a power spectrum of one set of parameters done!
# partial derivatives w.r.t cosmological parameters done!
# calculating and saving partial derivatives into temporary path: d:/large_array_temp/
# progress: 81/81
# partial derivatives done!
# loading partial derivatives and finishing simpson integration...
# progress: 3321/3321
# integration done!
# deleting temporary files...
# deleting done!
# -- Fisher matrix of redshift 0.1 saved into ../data/DESI_all/
# -- Fisher matrix of redshift 0.3 saved into ../data/DESI_all/
# -- Fisher matrix of redshift 0.5 saved into ../data/DESI_all/
# -- Fisher matrix of redshift 0.7 saved into ../data/DESI_all/
# -- Fisher matrix of redshift 0.9 saved into ../data/DESI_all/
# -- Fisher matrix of redshift 1.1 saved into ../data/DESI_all/
# -- Fisher matrix of redshift 1.3 saved into ../data/DESI_all/
# -- Fisher matrix of redshift 1.5 saved into ../data/DESI_all/
# -- Fisher matrix of redshift 1.7 saved into ../data/DESI_all/
# Fisher matrix saved into fisher.xlsx!
# all done!!!

# %%
import pandas as pd
cosmo_name=settings.var_name[:settings.cosmo_num]
fisher=pd.read_excel('fisher.xlsx',header=0,index_col=0)
fisher_valid=fisher.copy()
for index in fisher.index:
    if (fisher_valid.loc[index,:]==0).all():
        fisher_valid=fisher_valid.drop(index,axis=0)
        fisher_valid=fisher_valid.drop(index,axis=1)
fisher_valid.to_excel(settings.save_path+'valid.xlsx')
cov_valid=pd.DataFrame(np.linalg.inv(fisher_valid.values)[:settings.cosmo_num,:settings.cosmo_num],index=cosmo_name,columns=cosmo_name)

# %%
name_width=max([len(v) for v in cosmo_name])
error_dict=dict(zip(cosmo_name,np.sqrt(np.diag(cov_valid.values))))
print('1-sigma errors:')
for key in error_dict.keys():
    print(f'-- {key.rjust(name_width)}: {error_dict[key]:.1e}')
# Out:
# 1-sigma errors:
# -- omega_m0: 1.4e-02
# -- omega_b0: 3.5e-03
# --        h: 1.2e-02
# --      n_s: 3.2e-02
# --  sigma_8: 2.8e-02
# --     m_nu: 2.7e-01
# --    N_eff: 6.8e-01
# --       w0: 7.8e-02
# --       wa: 3.4e-01
