# %%
import numpy as np
import pandas as pd
from starfish.plot import *

# %%
from starfish.set import settings
settings.cosmo_value
# Out:
# [0.32, 0.049, 0.67, 0.96, 0.81, 0.06, 3.044, -1, 0]

# %%
def var_filter(fisher,lcdm,neff_fixed):
    df=fisher.copy()
    if lcdm:
        df=df.drop('w0',axis=0)
        df=df.drop('w0',axis=1)
        df=df.drop('wa',axis=0)
        df=df.drop('wa',axis=1)
    if neff_fixed:
        df=df.drop('N_eff',axis=0)
        df=df.drop('N_eff',axis=1)

    return df

# %% [markdown]
# # nuisance parameters of different tracers/surveys should be independent of each other

# %%
DESI_multi=var_filter(pd.read_excel('../data/DESI_all/valid.xlsx',header=0,index_col=0),lcdm=False,neff_fixed=False)
cov=pd.DataFrame(np.linalg.inv(DESI_multi.values),index=DESI_multi.index,columns=DESI_multi.columns)
DESI_multi_valid=np.linalg.inv(cov.iloc[:settings.cosmo_num,:settings.cosmo_num].values)

# %% [markdown]
# # SO + LiteBIRD + DESI multitracer

# %%
cmb_fisher=var_filter(pd.read_excel('../data/CMB/all.xlsx',header=0,index_col=0),lcdm=False,neff_fixed=False)
cmb_fisher
# Out:
#               omega_m0      omega_b0             h           n_s  \
# omega_m0  2.147834e+08 -7.541764e+08  1.650643e+08 -4.990171e+06
# omega_b0 -7.541764e+08  3.045160e+09 -5.322297e+08  3.220158e+07
# h         1.650643e+08 -5.322297e+08  1.371531e+08 -2.256316e+06
# n_s      -4.990171e+06  3.220158e+07 -2.256316e+06  1.126557e+06
# sigma_8  -6.793243e+07  2.430377e+08 -4.712226e+07  1.775017e+06
# m_nu     -1.477549e+07  5.176599e+07 -9.843028e+06  3.317576e+05
# N_eff    -7.638291e+06  2.567687e+07 -6.503294e+06  1.191634e+05
# tau       5.285179e+07 -1.876023e+08  3.669686e+07 -1.355804e+06
# w0        1.526209e+06 -7.272188e+06  3.577965e+06 -1.478760e+05
# wa       -4.385824e+04 -3.472015e+05  6.514719e+05 -2.843706e+04
#
#                sigma_8          m_nu         N_eff           tau  \
# omega_m0 -6.793243e+07 -1.477549e+07 -7.638291e+06  5.285179e+07
# omega_b0  2.430377e+08  5.176599e+07  2.567687e+07 -1.876023e+08
# h        -4.712226e+07 -9.843028e+06 -6.503294e+06  3.669686e+07
# n_s       1.775017e+06  3.317576e+05  1.191634e+05 -1.355804e+06
# sigma_8   2.652467e+07  6.277010e+06  1.876784e+06 -2.060786e+07
# m_nu      6.277010e+06  1.541394e+06  3.540514e+05 -4.902868e+06
# N_eff     1.876784e+06  3.540514e+05  3.324630e+05 -1.457025e+06
# tau      -2.060786e+07 -4.902868e+06 -1.457025e+06  1.635373e+07
# w0        2.218886e+06  7.908602e+05 -3.412282e+05 -1.773297e+06
# wa        7.789363e+05  2.565598e+05 -7.979409e+04 -6.193605e+05
#
#                     w0             wa
# omega_m0  1.526209e+06  -43858.240484
# omega_b0 -7.272188e+06 -347201.477824
# h         3.577965e+06  651471.937061
# n_s      -1.478760e+05  -28437.056773
# sigma_8   2.218886e+06  778936.336670
# m_nu      7.908602e+05  256559.839365
# N_eff    -3.412282e+05  -79794.086125
# tau      -1.773297e+06 -619360.547727
# w0        1.552171e+06  435641.832226
# wa        4.356418e+05  123324.164109

# %%
cmb_cov=pd.DataFrame(np.linalg.inv(cmb_fisher.values),index=cmb_fisher.index,columns=cmb_fisher.columns)
cmb_cov_marg=cmb_cov.drop('tau',axis=0)
cmb_cov_marg=cmb_cov_marg.drop('tau',axis=1)
cmb_fisher_marg=pd.DataFrame(np.linalg.inv(cmb_cov_marg),index=settings.var_name,columns=settings.var_name)
cmb_fisher_marg
# Out:
#               omega_m0      omega_b0             h           n_s  \
# omega_m0  4.397760e+07 -1.478854e+08  4.646782e+07 -6.085000e+05
# omega_b0 -1.478854e+08  8.930742e+08 -1.112605e+08  1.664844e+07
# h         4.646782e+07 -1.112605e+08  5.480743e+07  7.860325e+05
# n_s      -6.085000e+05  1.664844e+07  7.860325e+05  1.014154e+06
# sigma_8  -1.332188e+06  6.633934e+06 -8.793651e+05  6.652502e+04
# m_nu      1.069536e+06 -4.477407e+06  1.158735e+06 -7.471398e+04
# N_eff    -2.929495e+06  8.962561e+06 -3.233810e+06 -1.631060e+03
# w0        7.257129e+06 -2.761462e+07  7.557145e+06 -2.948910e+05
# wa        1.957784e+06 -7.452216e+06  2.041283e+06 -7.978507e+04
#
#                sigma_8          m_nu         N_eff            w0            wa
# omega_m0 -1.332188e+06  1.069536e+06 -2.929495e+06  7.257129e+06  1.957784e+06
# omega_b0  6.633934e+06 -4.477407e+06  8.962561e+06 -2.761462e+07 -7.452216e+06
# h        -8.793651e+05  1.158735e+06 -3.233810e+06  7.557145e+06  2.041283e+06
# n_s       6.652502e+04 -7.471398e+04 -1.631060e+03 -2.948910e+05 -7.978507e+04
# sigma_8   5.560451e+05  9.874888e+04  4.073989e+04 -1.570282e+04 -1.539849e+03
# m_nu      9.874888e+04  7.150858e+04 -8.276648e+04  2.592236e+05  7.087480e+04
# N_eff     4.073989e+04 -8.276648e+04  2.026503e+05 -4.992189e+05 -1.349756e+05
# w0       -1.570282e+04  2.592236e+05 -4.992189e+05  1.359885e+06  3.684822e+05
# wa       -1.539849e+03  7.087480e+04 -1.349756e+05  3.684822e+05  9.986728e+04

# %%
fisher1_combined=DESI_multi_valid+cmb_fisher_marg
fisher1_combined.to_excel('../data/combined/cmb+dmul-w0wacdm-free.xlsx')
cov1_combined=pd.DataFrame(np.linalg.inv(fisher1_combined),index=fisher1_combined.index,columns=fisher1_combined.columns)
cov1_combined
# Out:
#               omega_m0      omega_b0             h           n_s  \
# omega_m0  6.847356e-06  4.503023e-07 -2.384440e-06  1.058104e-06
# omega_b0  4.503023e-07  1.082914e-07 -7.077355e-07 -5.486050e-08
# h        -2.384440e-06 -7.077355e-07  5.082785e-06  5.517727e-07
# n_s       1.058104e-06 -5.486050e-08  5.517727e-07  4.139143e-06
# sigma_8  -8.316756e-06 -6.476724e-07  4.088788e-06 -1.634991e-07
# m_nu      7.061116e-05 -2.306609e-06  2.167678e-05  6.994374e-06
# N_eff     4.466047e-05 -1.570107e-06  2.592271e-05  4.372366e-05
# w0        4.007047e-05  6.492144e-06 -3.813392e-05  2.041207e-05
# wa       -1.885097e-04 -1.076191e-05  5.077275e-05 -5.417512e-05
#
#                sigma_8      m_nu     N_eff        w0        wa
# omega_m0 -8.316756e-06  0.000071  0.000045  0.000040 -0.000189
# omega_b0 -6.476724e-07 -0.000002 -0.000002  0.000006 -0.000011
# h         4.088788e-06  0.000022  0.000026 -0.000038  0.000051
# n_s      -1.634991e-07  0.000007  0.000044  0.000020 -0.000054
# sigma_8   2.269680e-05 -0.000154 -0.000006 -0.000067  0.000379
# m_nu     -1.540293e-04  0.001904  0.000510  0.000093 -0.002997
# N_eff    -6.011089e-06  0.000510  0.001131  0.000264 -0.001295
# w0       -6.685553e-05  0.000093  0.000264  0.000886 -0.002483
# wa        3.788424e-04 -0.002997 -0.001295 -0.002483  0.011351

# %%
name_width=max([len(v) for v in settings.var_name])
error_dict=dict(zip(settings.var_name,np.sqrt(np.diag(cov1_combined.values))))
print('1-sigma errors:')
for key in error_dict.keys():
    print(f'-- {key.rjust(name_width)}: {error_dict[key]:.1e}')
# Out:
# 1-sigma errors:
# -- omega_m0: 2.6e-03
# -- omega_b0: 3.3e-04
# --        h: 2.3e-03
# --      n_s: 2.0e-03
# --  sigma_8: 4.8e-03
# --     m_nu: 4.4e-02
# --    N_eff: 3.4e-02
# --       w0: 3.0e-02
# --       wa: 1.1e-01
