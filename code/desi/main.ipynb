# %%
import numpy as np
from starfish.set import settings

# %%
from starfish.galaxy.power import P_lin_w0wacdm
from starfish.plot import check_wiggle
pars,res,PK=P_lin_w0wacdm(*settings.cosmo_value)
check_wiggle(PK,window_array=settings.window_len)

# %%
from starfish.galaxy.fisher import get_Fisher
fisher=get_Fisher(lcdm=False)
# Out:
# process started!
# fiducial biases and volumes:
# (z = 0.7)
# -- b_fid: 1.37
# -- V_fid: 5.14e+09
# (z = 0.9)
# -- b_fid: 1.57
# -- V_fid: 6.73e+09
# (z = 1.1)
# -- b_fid: 1.80
# -- V_fid: 8.01e+09
# (z = 1.3)
# -- b_fid: 2.06
# -- V_fid: 8.99e+09
# (z = 1.5)
# -- b_fid: 2.34
# -- V_fid: 9.71e+09
# (z = 1.7)
# -- b_fid: 2.64
# -- V_fid: 1.02e+10
# fiducial values:
# -- omega_m0: 0.3200000900104817
# -- omega_b0: 0.049
# --        h: 0.67
# --      n_s: 0.96
# --  sigma_8: 0.8099999999999994
# --     m_nu: 0.06000375968353048
# --    N_eff: 3.0440000000000005
# --       w0: -1.0
# --       wa: 0.0
# --     p_s1: 0.0
# --     p_s2: 0.0
# --     p_s3: 0.0
# --     p_s4: 0.0
# --     p_s5: 0.0
# --     p_s6: 0.0
# --    lnbs1: -0.2581744487503041
# --    lnbs2: -0.2097663323601275
# --    lnbs3: -0.1603194126496827
# --    lnbs4: -0.11054349198268575
# --    lnbs5: -0.060982509826760886
# --    lnbs6: -0.012032762919894467
# calculating fiducial H(z), DA(z) and f(z,k)...  done!
# all necessary fiducial values done!
# calculating partial derivatives w.r.t cosmological parameters...
# (01/18) a power spectrum of one set of parameters done!
# (02/18) a power spectrum of one set of parameters done!
# (03/18) a power spectrum of one set of parameters done!
# (04/18) a power spectrum of one set of parameters done!
# (05/18) a power spectrum of one set of parameters done!
# (06/18) a power spectrum of one set of parameters done!
# (07/18) a power spectrum of one set of parameters done!
# (08/18) a power spectrum of one set of parameters done!
# (09/18) a power spectrum of one set of parameters done!
# (10/18) a power spectrum of one set of parameters done!
# (11/18) a power spectrum of one set of parameters done!
# (12/18) a power spectrum of one set of parameters done!
# (13/18) a power spectrum of one set of parameters done!
# (14/18) a power spectrum of one set of parameters done!
# (15/18) a power spectrum of one set of parameters done!
# (16/18) a power spectrum of one set of parameters done!
# (17/18) a power spectrum of one set of parameters done!
# (18/18) a power spectrum of one set of parameters done!
# partial derivatives w.r.t cosmological parameters done!
# calculating partial derivatives w.r.t nuisance parameters...
# partial derivatives w.r.t nuisance parameters done!
# partial derivatives done!
# saving results of cross product into temporary path: d:/large_array_temp/
# progress: 231/231
# saving done!
# loading cross products and finishing simpson integration...
# progress: 441/441
# loading done!
# deleting temporary files...
# deleting done!
# -- Fisher matrix of redshift 0.7 saved into ../data/DESI_QSO/
# -- Fisher matrix of redshift 0.9 saved into ../data/DESI_QSO/
# -- Fisher matrix of redshift 1.1 saved into ../data/DESI_QSO/
# -- Fisher matrix of redshift 1.3 saved into ../data/DESI_QSO/
# -- Fisher matrix of redshift 1.5 saved into ../data/DESI_QSO/
# -- Fisher matrix of redshift 1.7 saved into ../data/DESI_QSO/
# integration done!
# Fisher matrix saved into ../data/DESI_QSO/fisher.xlsx!
# all done!!!

# %%
import pandas as pd
cov=pd.DataFrame(np.linalg.inv(fisher.values),index=fisher.index,columns=fisher.columns)

# %%
name_width=max([len(v) for v in settings.var_name])
error_dict=dict(zip(settings.var_name,np.sqrt(np.diag(cov.values))))
print('1-sigma errors:')
for key in error_dict.keys():
    print(f'-- {key.rjust(name_width)}: {error_dict[key]:.1e}')
# Out:
# 1-sigma errors:
# -- omega_m0: 1.1e-01
# -- omega_b0: 2.6e-02
# --        h: 6.4e-02
# --      n_s: 2.0e-01
# --  sigma_8: 1.6e-01
# --     m_nu: 1.0e+00
# --    N_eff: 3.8e+00
# --       w0: 7.6e-01
# --       wa: 3.1e+00
# --     p_s1: 1.1e+02
# --     p_s2: 1.1e+02
# --     p_s3: 1.1e+02
# --     p_s4: 1.1e+02
# --     p_s5: 1.2e+02
# --     p_s6: 1.3e+02
# --    lnbs1: 1.5e-01
# --    lnbs2: 1.5e-01
# --    lnbs3: 1.5e-01
# --    lnbs4: 1.5e-01
# --    lnbs5: 1.4e-01
# --    lnbs6: 1.4e-01
