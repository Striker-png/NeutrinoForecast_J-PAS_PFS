# %%
import numpy as np
from starfish.set import settings

# %%
from starfish.galaxy.power import P_lin_w0wacdm
from starfish.plot import check_wiggle
pars,res,PK=P_lin_w0wacdm(*settings.cosmo_value)
check_wiggle(PK,window_array=settings.window_len)

# %%
from starfish.galaxy.multitracer import get_Fisher
fisher=get_Fisher(lcdm=False)
# Out:
# process started!
# fiducial volumes:
# V_fid (0.3) = 9.27e+08
# V_fid (0.5) = 2.02e+09
# V_fid (0.7) = 3.12e+09
# V_fid (0.9) = 4.08e+09
# V_fid (1.1) = 4.86e+09
# V_fid (1.3) = 5.46e+09
# V_fid (1.5) = 5.89e+09
# V_fid (1.7) = 6.20e+09
# V_fid (1.9) = 6.39e+09
# V_fid (2.1) = 6.51e+09
# V_fid (2.3) = 6.56e+09
# V_fid (2.5) = 6.56e+09
# V_fid (2.7) = 6.52e+09
# V_fid (2.9) = 6.46e+09
# V_fid (3.1) = 6.38e+09
# V_fid (3.3) = 6.28e+09
# V_fid (3.5) = 6.17e+09
# V_fid (3.7) = 6.06e+09
# V_fid (3.9) = 5.94e+09
# fiducial biases:
# #################### tracer: LRG ####################
# b_fid (0.3) = 2.00
# b_fid (0.5) = 2.22
# b_fid (0.7) = 2.45
# b_fid (0.9) = 2.69
# b_fid (1.1) = 2.93
# b_fid (1.3) = 3.19
# b_fid (1.5) = 3.44
# b_fid (1.7) = 3.70
# b_fid (1.9) = 3.96
# b_fid (2.1) = 4.22
# b_fid (2.3) = 4.49
# b_fid (2.5) = 4.75
# b_fid (2.7) = 5.02
# b_fid (2.9) = 5.28
# b_fid (3.1) = 5.55
# b_fid (3.3) = 5.82
# b_fid (3.5) = 6.08
# b_fid (3.7) = 6.35
# b_fid (3.9) = 6.62
# #################### tracer: ELG ####################
# b_fid (0.3) = 0.99
# b_fid (0.5) = 1.09
# b_fid (0.7) = 1.21
# b_fid (0.9) = 1.33
# b_fid (1.1) = 1.45
# b_fid (1.3) = 1.57
# b_fid (1.5) = 1.70
# b_fid (1.7) = 1.83
# b_fid (1.9) = 1.96
# b_fid (2.1) = 2.09
# b_fid (2.3) = 2.22
# b_fid (2.5) = 2.35
# b_fid (2.7) = 2.48
# b_fid (2.9) = 2.61
# b_fid (3.1) = 2.74
# b_fid (3.3) = 2.87
# b_fid (3.5) = 3.01
# b_fid (3.7) = 3.14
# b_fid (3.9) = 3.27
# #################### tracer: QSO ####################
# b_fid (0.3) = 1.02
# b_fid (0.5) = 1.18
# b_fid (0.7) = 1.37
# b_fid (0.9) = 1.57
# b_fid (1.1) = 1.80
# b_fid (1.3) = 2.06
# b_fid (1.5) = 2.34
# b_fid (1.7) = 2.64
# b_fid (1.9) = 2.96
# b_fid (2.1) = 3.31
# b_fid (2.3) = 3.68
# b_fid (2.5) = 4.07
# b_fid (2.7) = 4.49
# b_fid (2.9) = 4.93
# b_fid (3.1) = 5.39
# b_fid (3.3) = 5.87
# b_fid (3.5) = 6.38
# b_fid (3.7) = 6.91
# b_fid (3.9) = 7.47
# fiducial values:
# --    omega_m0: 0.3200000900104817
# --    omega_b0: 0.049
# --           h: 0.67
# --         n_s: 0.96
# --     sigma_8: 0.8099999999999994
# --        m_nu: 0.06000375968353048
# --       N_eff: 3.0440000000000005
# --          w0: -1.0
# --          wa: 0.0
# --   p_s1(LRG): 0.0
# --   p_s1(ELG): 0.0
# --   p_s1(QSO): 0.0
# --   p_s2(LRG): 0.0
# --   p_s2(ELG): 0.0
# --   p_s2(QSO): 0.0
# --   p_s3(LRG): 0.0
# --   p_s3(ELG): 0.0
# --   p_s3(QSO): 0.0
# --   p_s4(LRG): 0.0
# --   p_s4(ELG): 0.0
# --   p_s4(QSO): 0.0
# --   p_s5(LRG): 0.0
# --   p_s5(ELG): 0.0
# --   p_s5(QSO): 0.0
# --   p_s6(LRG): 0.0
# --   p_s6(ELG): 0.0
# --   p_s6(QSO): 0.0
# --   p_s7(LRG): 0.0
# --   p_s7(ELG): 0.0
# --   p_s7(QSO): 0.0
# --   p_s8(LRG): 0.0
# --   p_s8(ELG): 0.0
# --   p_s8(QSO): 0.0
# --   p_s9(LRG): 0.0
# --   p_s9(ELG): 0.0
# --   p_s9(QSO): 0.0
# --  p_s10(LRG): 0.0
# --  p_s10(ELG): 0.0
# --  p_s10(QSO): 0.0
# --  p_s11(LRG): 0.0
# --  p_s11(ELG): 0.0
# --  p_s11(QSO): 0.0
# --  p_s12(LRG): 0.0
# --  p_s12(ELG): 0.0
# --  p_s12(QSO): 0.0
# --  p_s13(LRG): 0.0
# --  p_s13(ELG): 0.0
# --  p_s13(QSO): 0.0
# --  p_s14(LRG): 0.0
# --  p_s14(ELG): 0.0
# --  p_s14(QSO): 0.0
# --  p_s15(LRG): 0.0
# --  p_s15(ELG): 0.0
# --  p_s15(QSO): 0.0
# --  p_s16(LRG): 0.0
# --  p_s16(ELG): 0.0
# --  p_s16(QSO): 0.0
# --  p_s17(LRG): 0.0
# --  p_s17(ELG): 0.0
# --  p_s17(QSO): 0.0
# --  p_s18(LRG): 0.0
# --  p_s18(ELG): 0.0
# --  p_s18(QSO): 0.0
# --  p_s19(LRG): 0.0
# --  p_s19(ELG): 0.0
# --  p_s19(QSO): 0.0
# --  lnbs1(LRG): 0.3246322687909391
# --  lnbs1(ELG): -0.3803493694160091
# --  lnbs1(QSO): -0.34829658645177464
# --  lnbs2(LRG): 0.3250095842556625
# --  lnbs2(ELG): -0.37997205395128547
# --  lnbs2(QSO): -0.3046754837527075
# --  lnbs3(LRG): 0.3253817246951857
# --  lnbs3(ELG): -0.3795999135117623
# --  lnbs3(QSO): -0.25817444875030454
# --  lnbs4(LRG): 0.32574476793916307
# --  lnbs4(ELG): -0.3792368702677852
# --  lnbs4(QSO): -0.20976633235809844
# --  lnbs5(LRG): 0.32609693395252887
# --  lnbs5(ELG): -0.3788847042544194
# --  lnbs5(QSO): -0.1603194126496827
# --  lnbs6(LRG): 0.3264377744228482
# --  lnbs6(ELG): -0.37854386378409993
# --  lnbs6(QSO): -0.11054349163309497
# --  lnbs7(LRG): 0.32676725852371474
# --  lnbs7(ELG): -0.3782143796832334
# --  lnbs7(QSO): -0.06098250982143764
# --  lnbs8(LRG): 0.3270862401842893
# --  lnbs8(ELG): -0.37789539802265887
# --  lnbs8(QSO): -0.012032762919894467
# --  lnbs9(LRG): 0.3273954027625089
# --  lnbs9(ELG): -0.37758623544443937
# --  lnbs9(QSO): 0.036029768155158286
# -- lnbs10(LRG): 0.32769531983710215
# -- lnbs10(ELG): -0.3772863183698459
# -- lnbs10(QSO): 0.08302219478668964
# -- lnbs11(LRG): 0.3279869076272129
# -- lnbs11(ELG): -0.3769947305797353
# -- lnbs11(QSO): 0.12883127415662915
# -- lnbs12(LRG): 0.3282708294248507
# -- lnbs12(ELG): -0.37671080878209745
# -- lnbs12(QSO): 0.17339452233169364
# -- lnbs13(LRG): 0.328547620373727
# -- lnbs13(ELG): -0.3764340178332211
# -- lnbs13(QSO): 0.21668591378250432
# -- lnbs14(LRG): 0.3288180661898998
# -- lnbs14(ELG): -0.37616357201704836
# -- lnbs14(QSO): 0.2587050179464574
# -- lnbs15(LRG): 0.32908258957582437
# -- lnbs15(ELG): -0.37589904863112367
# -- lnbs15(QSO): 0.2994690832142943
# -- lnbs16(LRG): 0.3293416321994779
# -- lnbs16(ELG): -0.37564000600747016
# -- lnbs16(QSO): 0.33900723927534615
# -- lnbs17(LRG): 0.3295955777084195
# -- lnbs17(ELG): -0.3753860604985286
# -- lnbs17(QSO): 0.37735630288366256
# -- lnbs18(LRG): 0.32984496312219086
# -- lnbs18(ELG): -0.37513667508475723
# -- lnbs18(QSO): 0.41455781515215573
# -- lnbs19(LRG): 0.33009020270048417
# -- lnbs19(ELG): -0.3748914355064639
# -- lnbs19(QSO): 0.4506558175051727
# calculating fiducial H(z), DA(z) and f(z,k)...  done!
# all necessary fiducial values done!
# calculating partial derivatives w.r.t cosmological parameters...
# (01/18) a power spectrum of one set of parameters done!
# (02/18) a power spectrum of one set of parameters done!
# (03/18) a power spectrum of one set of parameters done!
# (04/18) a power spectrum of one set of parameters done!
# (05/18) a power spectrum of one set of parameters done!
# (06/18) a power spectrum of one set of parameters done!
# (07/18) a power spectrum of one set of parameters done!
# (08/18) a power spectrum of one set of parameters done!
# (09/18) a power spectrum of one set of parameters done!
# (10/18) a power spectrum of one set of parameters done!
# (11/18) a power spectrum of one set of parameters done!
# (12/18) a power spectrum of one set of parameters done!
# (13/18) a power spectrum of one set of parameters done!
# (14/18) a power spectrum of one set of parameters done!
# (15/18) a power spectrum of one set of parameters done!
# (16/18) a power spectrum of one set of parameters done!
# (17/18) a power spectrum of one set of parameters done!
# (18/18) a power spectrum of one set of parameters done!
# partial derivatives w.r.t cosmological parameters done!
# calculating and saving partial derivatives into temporary path: d:/large_array_temp/
# progress: 123/123
# partial derivatives done!
# loading partial derivatives and finishing simpson integration...
# progress: 7626/7626
# integration done!
# deleting temporary files...
# deleting done!
# -- Fisher matrix of redshift 0.3 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 0.5 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 0.7 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 0.9 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 1.1 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 1.3 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 1.5 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 1.7 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 1.9 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 2.1 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 2.3 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 2.5 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 2.7 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 2.9 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 3.1 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 3.3 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 3.5 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 3.7 saved into ../data/jpas_all/
# -- Fisher matrix of redshift 3.9 saved into ../data/jpas_all/
# Fisher matrix saved into ../data/jpas_all/fisher.xlsx!
# all done!!!

# %%
import pandas as pd
cosmo_name=settings.var_name[:settings.cosmo_num]
fisher_valid=fisher.copy()
for index in fisher.index:
    if (fisher_valid.loc[index,:]==0).all():
        fisher_valid=fisher_valid.drop(index,axis=0)
        fisher_valid=fisher_valid.drop(index,axis=1)
fisher_valid.to_excel(settings.save_path+'valid.xlsx')
cov_valid=pd.DataFrame(np.linalg.inv(fisher_valid.values)[:settings.cosmo_num,:settings.cosmo_num],index=cosmo_name,columns=cosmo_name)

# %%
name_width=max([len(v) for v in cosmo_name])
error_dict=dict(zip(cosmo_name,np.sqrt(np.diag(cov_valid.values))))
print('1-sigma errors:')
for key in error_dict.keys():
    print(f'-- {key.rjust(name_width)}: {error_dict[key]:.1e}')
# Out:
# 1-sigma errors:
# -- omega_m0: 1.5e-02
# -- omega_b0: 4.1e-03
# --        h: 1.6e-02
# --      n_s: 1.9e-02
# --  sigma_8: 2.9e-02
# --     m_nu: 3.1e-01
# --    N_eff: 6.1e-01
# --       w0: 1.0e-01
# --       wa: 4.7e-01
